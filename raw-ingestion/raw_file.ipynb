# %%
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/")
# Out:
# True

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/raw")
dbutils.fs.ls("dbfs:/FileStore/vijay_project/raw/flights")
# Out:
# [FileInfo(path='dbfs:/FileStore/vijay_project/raw/flights/flights.csv', name='flights.csv', size=592406591, modificationTime=1767090623000)]

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/bronze")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/bronze/batch_data")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/bronze/streaming_data")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/bronze/streaming_data/flights")
# Out:
# True

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/check_point/flights")
dbutils.fs.ls("dbfs:/FileStore/vijay_project/check_point/")
# Out:
# [FileInfo(path='dbfs:/FileStore/vijay_project/check_point/flights/', name='flights/', size=0, modificationTime=1767111371000)]

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/silver")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/silver/flights")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/silver/airports")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/silver/airlines")
dbutils.fs.ls("dbfs:/FileStore/vijay_project/silver/")
# Out:
# [FileInfo(path='dbfs:/FileStore/vijay_project/silver/flights/', name='flights/', size=0, modificationTime=1767078663000)]

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/gold")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/gold/flight_fact")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/gold/airline_dim_scd")
dbutils.fs.mkdirs("dbfs:/FileStore/vijay_project/gold/airport_dim")
